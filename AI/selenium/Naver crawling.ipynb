# %%
import pandas as pd
import numpy as np

url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver'
ranking = pd.read_html(url, encoding="utf-8")[0]
ranking
# Out:
#     순위               영화명  변동폭  변동폭.1  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0  NaN               NaN  NaN    NaN         NaN         NaN         NaN
# 1  NaN                인질  NaN    0.0         NaN         NaN         NaN
# 2  NaN              모가디슈  NaN    0.0         NaN         NaN         NaN
# 3  NaN      샹치와 텐 링즈의 전설  NaN    2.0         NaN         NaN         NaN
# 4  NaN             레미니센스  NaN    1.0         NaN         NaN         NaN
# 5  NaN               싱크홀  NaN    1.0         NaN         NaN         NaN
# 6  NaN                귀신  NaN    0.0         NaN         NaN         NaN
# 7  NaN             프리 가이  NaN    1.0         NaN         NaN         NaN
# 8  NaN            여름날 우리  NaN    1.0         NaN         NaN         NaN
# 9  NaN                귀문  NaN    0.0         NaN         NaN         NaN
# 10 NaN                올드  NaN    0.0         NaN         NaN         NaN
# 11 NaN               NaN  NaN    NaN         NaN         NaN         NaN
# ...

# %%
# ranking = ranking[ranking["영화명"].notnull()]
# ranking
ranking = ranking[ranking["영화명"].notnull()]
ranking
# Out:
#     순위               영화명  변동폭  변동폭.1  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 1  NaN                인질  NaN    0.0         NaN         NaN         NaN
# 2  NaN              모가디슈  NaN    0.0         NaN         NaN         NaN
# 3  NaN      샹치와 텐 링즈의 전설  NaN    2.0         NaN         NaN         NaN
# 4  NaN             레미니센스  NaN    1.0         NaN         NaN         NaN
# 5  NaN               싱크홀  NaN    1.0         NaN         NaN         NaN
# 6  NaN                귀신  NaN    0.0         NaN         NaN         NaN
# 7  NaN             프리 가이  NaN    1.0         NaN         NaN         NaN
# 8  NaN            여름날 우리  NaN    1.0         NaN         NaN         NaN
# 9  NaN                귀문  NaN    0.0         NaN         NaN         NaN
# 10 NaN                올드  NaN    0.0         NaN         NaN         NaN
# 12 NaN        맨 인 더 다크 2  NaN    2.0         NaN         NaN         NaN
# 13 NaN             최선의 삶  NaN    4.0         NaN         NaN         NaN
# ...

# %%
ranking["순위"] = np.arange(1, 51)
# Out:
# <ipython-input-193-eca0982fc5f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ranking["순위"] = np.arange(1, 51)

# %%
ranking.set_index("순위")[["영화명", "변동폭.1"]]
# Out:
#                  영화명  변동폭.1
# 순위
# 1                 인질    0.0
# 2               모가디슈    0.0
# 3       샹치와 텐 링즈의 전설    2.0
# 4              레미니센스    1.0
# 5                싱크홀    1.0
# 6                 귀신    0.0
# 7              프리 가이    1.0
# 8             여름날 우리    1.0
# 9                 귀문    0.0
# 10                올드    0.0
# 11        맨 인 더 다크 2    2.0
# 12             최선의 삶    4.0
# 13       더 수어사이드 스쿼드    2.0
# 14            그린 나이트    2.0
# 15                코다    2.0
# 16          습도 다소 높음   14.0
# 17              바쿠라우    5.0
# 18        건파우더 밀크셰이크    3.0
# 19               데미지    5.0
# 20            블랙 위도우    1.0
# 21     스파이더맨: 노 웨이 홈    6.0
# 22              스틸워터    4.0
# 23              이터널스    3.0
# 24                자마   22.0
# 25  베놈 2: 렛 데어 비 카니지    1.0
# 26       퍼피 구조대 더 무비    3.0
# 27                랑종    2.0
# 28     꽃다발 같은 사랑을 했다    1.0
# 29            날씨의 아이    3.0
# 30              켈리 갱    2.0
# 31               보이스    5.0
# 32          디스 아메리카노    3.0
# ...
