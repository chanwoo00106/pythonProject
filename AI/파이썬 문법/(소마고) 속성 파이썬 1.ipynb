# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ※ 파이썬 홈페이지  : https://www.python.org/
# * 주참고자료 :  파이썬 코딩도장 (길벗), COS PRO 2급 파이썬 (길벗)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. 기본 문법 알아보기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.1. 세미콜론
# * 파이썬은 세미콜론을 붙이지 않음

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# * 보통 한 줄에 여러 구문을 사용할 때 세미콜론으로 구분해줌

# %%
print(1); print(2)

# %% [markdown]
# ### 1.2 주석
# * 주석
# 코드 맨 앞에 #을 사용하면 해당 줄은 모두 주석이 됨

# %%
# 2021년 8월 30일
# 광주소프트웨어 마이스터 고등학교
# 인공지능 교육

# %% [markdown]
# * 코드 뒤에 주석을 작성할 수도 있음

# %%
# print('Hello')

# %% [markdown]
# ### 1.3 들여쓰기
# * 코드를 읽기 쉽도록 일정한 간격을 띄워서 작성하는 방법
# * 파이썬은 들여쓰기 자체가 문법
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# #### 들여쓰기 방법
# * 공백(스페이스) 2칸, 4칸, 탭(tab) 등 여러 가지 방법이 있음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 코드 블록
# * 특정한 동작을 위해서 코드가 모여 있는 상태
# * 파이썬은 들여쓰기를 기준으로 코드 블록을 구성
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. 숫자 계산하기

# %% [markdown]
# * 정수 계산 : 덧셈 / 뺄셈 / 곱셈 / 나눗셈

# %%
1 + 1
# Out:
# 2

# %%
3 + 5
# Out:
# 8

# %%
10 - 3
# Out:
# 7

# %%
3 * 5
# Out:
# 15

# %%
4 / 2
# Out:
# 2.0

# %% [markdown]
# * 실수 계산 : 덧셈 / 뺄셈 / 곱셈 / 나눗셈

# %%
3.5 + 1.2
# Out:
# 4.7

# %%
4.3 - 2.7
# Out:
# 1.5999999999999996

# %%
1.4 * 3.1
# Out:
# 4.34

# %%
5.5 / 3.1
# Out:
# 1.7741935483870968

# %% [markdown]
# * 실수와 정수의 계산
# ![image.png](attachment:image.png)

# %%
4.2 + 5
# Out:
# 9.2

# %%
3 * 2.0
# Out:
# 6.0

# %%
type(3)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %%
type(1 + 2j)
# Out:
# complex

# %%
1j ** 2 # i
# Out:
# (-1+0j)

# %% [markdown]
# ## 3. 변수 사용하기

# %% [markdown]
# **변수 명명 규칙**
# - 영문 문자와 숫자를 사용할 수 있다
# - 대소문자를 구분한다
# -문자부터 시작해야 하며 숫자부터 시작하면 안 된다
# - _(밑줄 문자)로 시작할 수 있다
# - 특수 문자(+, -, *, /, $, @, &, % 등)는 사용할 수 없다
# - 파이썬의 키워드(if, for, while, and, or 등)는 사용할 수 없다
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.1 변수 만들기
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.2 변수 값 출력하기

# %%
x = 10
print(x)
y = 20
y

# %%
x
# Out:
# 10

# %% [markdown]
# ### 3.3 변수의 값 변경하기

# %%
x = 10
print(x)
# Out:
# 10

# %%
x = 20
x
# Out:
# 20

# %%
x = x + 30
x
# Out:
# 50

# %% [markdown]
# ### 3.4 변수 여러개를 한 번에 만들기

# %%
x, y, z = 10, 20, 30
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
x = 'hello'
x
# Out:
# 'hello'

# %%
x = y = z = 10
print(x,y,z)
# Out:
# 10 10 10

# %% [markdown]
# ### 3.5 변수에 다른 변수 할당하기
# * 값뿐만 아니라 다른 변수도 할당할 수 있음

# %%
x = 10
y = 20
x, y = y, x

# %%
x, y
# Out:
# (20, 10)

# %%
temp = x
x = y

y = temp

# %% [markdown]
# ### 3.6 변수 삭제하기

# %%
x = 10
del x
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-5ee6bfbd3ae2> in <module>
#       1 x = 10
#       2 del x
# ----> 3 print(x)
#
# NameError: name 'x' is not defined

# %%
print = 10

# %%
type(print)
# Out:
# int

# %%
print(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-e9b8b06bc415> in <module>
# ----> 1 print(1)
#
# TypeError: 'int' object is not callable

# %%
del print
type(print)
# Out:
# builtin_function_or_method

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ## 4. 문자열 사용하기

# %% [markdown]
# ### 4.1 문자열을 변수에 저장하기

# %%
hello = "'Hello', world!"
print(hello)
# Out:
# 'Hello', world!

# %%
type(hello)

# %% [markdown]
# * 여러 줄로 된 문자열을 변수에 저장하기

# %%
h = '''여러줄 문자열1
두번째줄
세번째줄
'''
print(h)

# %%
h
# Out:
# '여러줄 문자열1\n두번째줄\n세번째줄\n'

# %% [markdown]
# ### 4.2 문자열의 길이 (글자 수) 구하기
#
# * `len 함수`
#     - 공백까지 포함하여 계산함
#     - 문자열을 묶은 따옴표는 제외

# %%
len("안녕 하세요") # length
# Out:
# 6

# %%
len('abcd')
# Out:
# 4

# %% [markdown]
# ### 4.3 문자열을 연결하고 반복하기
#
# * 문자열1 + 문자열2

# %%
a = '강아지'
b = '고양이'
print(a + b)
a + b
# Out:
# 강아지고양이
# '강아지고양이'

# %% [markdown]
# * 문자열 * 정수

# %%
'Python ' * 3
# Out:
# 'Python Python Python '

# %%
3 * '파이썬 '
# Out:
# '파이썬 파이썬 파이썬 '

# %% [markdown]
# ### 4.4 문자열에 숫자를 더하는 방법
# * `문자열 + str(정수)`
# * `문자열 + str(실수)`

# %%
'문자열' + str(1)
# Out:
# '문자열1'

# %%
str(1)
# Out:
# '1'

# %% [markdown]
# ##### [연습문제]
# 다음 소스 코드를 완성하여 문자열의 길이가 출력되게 만드세요
# ![image.png](attachment:image.png)

# %%
s = 'Hello, Python'

# %%
print('s의 길이는 ' + str(len(s)) + '입니다.')
# Out:
# s의 길이는 13입니다.

# %%
print('s의 길이는 ', str(len(s)), '입니다.')
# Out:
# s의 길이는  13 입니다.

# %% [markdown]
# ## 5. 입력값을 변수에 저장하기
# ### 5.1 문자열 입력받기

# %%
input()
# Out:
# 10
# '10'

# %%
input("문자열을 입력하세요 : ")
# Out:
# 문자열을 입력하세요 : 인공지능
# '인공지능'

# %% [markdown]
# * `input`함수
# ```
#     변수 = input()
#     변수 = input(안내문자열)
# ```
#     `input('문자열을 입력하세요: ')`

# %% [markdown]
# ### 4.2 숫자 입력받기
# ![image.png](attachment:image.png)
#
# 덧셈 결과가 틀림... Why??

# %%
a = input('첫 번째 숫자를 입력 : ')
b = input('두 번째 숫자를 입력 : ')
print(a + b)
# Out:
# 첫 번째 숫자를 입력 : 100
# 두 번째 숫자를 입력 : 200
# 100200

# %%
int(a) + int(b)
# Out:
# 300

# %% [markdown]
# * 정수 입력받기
#     - 문자열 상태가 아닌 숫자로 변환해 주어야 함
#     - `변수 = int(input())`
#     ![image.png](attachment:image.png)

# %%
a = int(input('첫 번째 숫자를 입력 : '))
b = int(input('두 번째 숫자를 입력 : '))
print(a + b)

# %%
type(a)

# %%
type(int('100'))

# %% [markdown]
# ### 4.3 한 번에 값 두 개 이상 입력받기
#
# * Input 한 번에 여러 개 입력받기
#
#     - `변수1, 변수2 = input().split()`
#
#     ![image.png](attachment:image.png)

# %%
a, b = input('문자열 2개 입력 : ').split()

# %%
a, b

# %% [markdown]
# * 숫자 두 개는 어떻게 입력할까?

# %%
a, b = input('문자열 2개 입력 : ').split()
int(a) + int(b)
# Out:
# 문자열 2개 입력 : 10 20
# 30

# %% [markdown]
# *  split의 결과(여러개의 문자열)을 한꺼번에 int로 변환하기
#
#     `변수1, 변수2 = map(int, input().split())`
#
#     ![image-2.png](attachment:image-2.png)

# %%
a, b = map(int, input('문자열 2개 입력 :').split())
a, b
# Out:
# 문자열 2개 입력 :10 20
# (10, 20)

# %% [markdown]
# **[연습문제] 한번에 정수 세 개 입력받기**
# 다음 소스 코드를 완성하여 정수 세 개를 입력받고 합계가 출력되게 만드세요.
# ![image-2.png](attachment:image-2.png)

# %%
a, b, c = map(int, input('숫자 3개 입력 : ').split())
print(a + b + c)
# Out:
# 숫자 3개 입력 : 10 20 30
# 60

# %%
a, b, c = map(int, input('숫자 3개 입력 : ').split(','))
print(a + b + c)
# Out:
# 숫자 3개 입력 : 10,20,30
# 60

# %% [markdown]
# ## 5. 출력

# %% [markdown]
# ### 5.1 값 여러 개 출력
# * `print(값1, 값2, 값3)`
# * `print(변수1, 변수2, 변수3)`

# %%
print(1, 2, 3)
# Out:
# 1 2 3

# %%
print('Hello', "python")
# Out:
# Hello python

# %% [markdown]
# * `print(변수1, 변수2, sep='문자 또는 문자열')`
# ![image-2.png](attachment:image-2.png)

# %%
print(1, 2, 3, sep=',')
# Out:
# 1,2,3

# %%
print(4, 5, 6, sep=', ')
# Out:
# 4, 5, 6

# %% [markdown]
# ### 5.2 줄바꿈 활용
#
# print 한 번으로 값을 여러 줄에 출력하기
#
#
#     * sep에 개행 문자(\n)을 지정
#         print(1, 2, 3, sep='\n')
#
#     * \n: 값을 다음 줄에 출력하게 만드는 제어 문자
#    ![image-2.png](attachment:image-2.png)

# %%
print(1, 2, 3, sep='\n')
# Out:
# 1
# 2
# 3

# %%
print(1, 2, 3, sep='\t')
# Out:
# 1	2	3

# %% [markdown]
# ### 5.2 줄 바꿈 활용
# `print`를 여러 번 사용해서 print(1,2,3)처럼 한 줄에 여러 개의 값을 출력할 수는 없을까?
# ```
# print(값, end='문자 또는 문자열')
# print(변수, end='문자 또는 문자열')
# ```

# %%
print(1, end='\n')
print(2)
# Out:
# 1
# 2

# %%
print(1, end='')
print(2, end='')
print(3)
# Out:
# 123

# %% [markdown]
# `연습문제` 날짜와 시간 출력하기
#
# 다음 소스코드를 완성하여 날짜와 시간에 출력되게 만드세요
# ![image.png](attachment:image.png)

# %%
year = 2000
month = 10
day = 27
hour = 11
minute = 43
second = 59

print(year, month, day, sep='/', end=' ')
print(hour, minute, second, sep=':')
# Out:
# 2000/10/27 11:43:59

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 6. 산술연산자

# %% [markdown]
# ### 6.1 기본 산술 연산자
# ```
# 10 + 20  # 덧셈
# 10 - 20  # 뺄셈
# 10 * 20  # 곱셈
# 5 / 2    # 나눗셈
# 5 // 2   # 몫 (버림 나눗셈)
# 5 % 2    # 나머지
# divmod(5, 2)  # 몫과 나머지 한꺼번에 구하기
# 2 ** 10  # 거듭제곱
# ````

# %%
10 + 20
# Out:
# 30

# %%
10 - 20

# %%
10 * 20

# %%
5 / 2

# %%
5 // 2

# %%
5 % 2

# %%
divmod(5, 2)

# %%
2 ** 10

# %% [markdown]
# ### 6.2 할당 연산자
# * `a += b` : a와 b를 더한 후 결과를 다시 a에 저장

# %%
a = 10
b = 20
a += b
a
# Out:
# 30

# %% [markdown]
# * `-=`, `*=`, `/=`, `//=`, `%=` 도 같은 방식으로 가능

# %%
a -= b
a

# %%
a *= b
a

# %%
a /= b
a

# %%
a = 50
b = 20
a //= b
a
# Out:
# 2

# %%
a = 50
b = 20
a %= b
a
# Out:
# 10

# %% [markdown]
# ### 6.3 괄호 사용하기
# `1 + 2 * 3`
# vs.
# `(1 + 2) * 3`

# %%
1 + (2 * 3)
# Out:
# 7

# %%
(1 + 2) * 3
# Out:
# 9

# %% [markdown]
# **<연습문제> 점수 평균 구하기**
# ```
# kor = 94
# eng = 91
# math = 89
# sci = 83
#
# average = ________________________
# print(average)
#
# ```

# %%
kor = 94
eng = 91
math = 89
sci = 83
average = (kor + eng + math + sci) / 4
print(average)
# Out:
# 89.25

# %% [markdown]
# * 평균점수를 정수로 구하기 (무조건 내림)

# %%
kor = 94
eng = 91
math = 89
sci = 83
average = (kor + eng + math + sci) / 4
print(int(average))
# Out:
# 89

# %% [markdown]
# ## 7. 불과 비교, 논리 연산자

# %% [markdown]
# ### 7.1 불(Boolean)과 비교 연산자 사용
#
# * 불 연산자
#     - `True`
#     - `False`

# %%
type(True)
# Out:
# bool

# %%
3 > 1
# Out:
# True

# %% [markdown]
# * 비교 연산자
# >```
# 10 == 10   # 10과 10이 같은지
# 10 != 5    # 10과 5가 다른지
# 10 > 20    # 10이 20보다 큰지
# 10 < 20    # 10이 20보다 작은지
# 10 >= 10   # 10이 20보다 크거나 같은지
# 10 <= 10   # 10이 20보다 작거나 같은지
# ```

# %%
10 == 10
# Out:
# True

# %%
10 != 5

# %%
10 > 20

# %%
10 < 20

# %%
10 >= 10

# %%
10 <= 10

# %% [markdown]
# ### 7.2 논리 연산자
#
#     (1) and 연산자
# >```
# True and True   # True
# True and False  # False
# False and True  # False
# False and False # False
# ```

# %%
True and True

# %%
True and False

# %%
False and True

# %%
False and False

# %% [markdown]
#     (2) or 연산자
# >```
# True or True   # True
# True or False  # True
# False or True  # True
# False or False # False
# ```

# %%
True or True

# %%
True or False

# %%
False or True

# %%
False or False

# %% [markdown]
#     (3) not 연산자
#
# > ```
# not True     # False
# not False    # True
# ```

# %%
not True

# %%
not False

# %% [markdown]
#     (4) 정수, 실수, 문자열의 참,거짓
#
# >* 정수 0, 실수 0.0은 False, 나머지는 모두 True
# > ```
# bool(0)     # False
# bool(0.0)   # False
# bool(1)     # True
# bool(0.1)   # True
# bool(-100)  # True
# bool(1/3)   # True
# bool(-0.001)  # True
# ```

# %%
bool(0)

# %%
bool(0.0)

# %%
bool(1)

# %%
bool(0.1)

# %%
bool(-100)

# %%
bool(1/3)

# %%
bool(-0.001)

# %% [markdown]
#
# >* 문자열 '', "", None 만 False이고, 어떤 값이라도 있으면 True
# > ```
# bool('')      # False
# bool("")      # False
# bool(' ')     # True
# bool('False') # True
# bool('0')     # True
# bool('Hello') # True
# ```

# %%
bool('')

# %%
bool("")

# %%
bool(' ')

# %%
bool('False')

# %%
bool('0')

# %%
bool('Hello')

# %%
bool(None)

# %% [markdown]
# **<연습문제> 합격 여부 출력하기**
#
# 국어, 영어, 수학, 과학 점수가 있을 때 한 과목이라도 50점 미만이면 불합격이라고 정했습니다. 다음 소스 코드를 완성하여 합격이면 True, 불합격이면 False가 출력되게 만드세요
# >```
# kor = 92
# eng = 47
# math = 86
# sci = 81
# print(_____________________________________)
# ```
#
# `실행결과`
# False

# %%
kor = 92
eng = 47
math = 86
sci = 81
print(kor >= 50 and eng >= 50 and math >= 50 and sci >= 50)
# Out:
# False

# %%
kor = 92
eng = 47
math = 86
sci = 81
print(not(kor >= 50 or eng > 50 or math > 50 or sci > 50))
# Out:
# False

# %% [markdown]
# ## 8. if 조건문

# %% [markdown]
# ### 8.1 if 조건문
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
x = 5 
if x == 10:
    print('10입니다')
    
print("if 밖")
# Out:
# if 밖

# %% [markdown]
# * pass

# %%
if x == 10:
    pass
print('메인프로그램 영역')

# %%
if x == 10:
    print('x에 있는 숫자는')
    print('10입니다')

# %% [markdown]
# ### 8.2 if 조건문과 들여쓰기
# ![image.png](attachment:image.png)
# Error발생... Why?

# %% [markdown]
# **올바르게 고치려면?**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5
if x == 10:
    print('aaaaaa')
print('bbbbbb')
# Out:
# bbbbbb

# %% [markdown]
# **<연습문제>**
#
# 숫자 1개를 입력받아, 그 입력받은 숫자가 10이면 "10입니다", 20이면 "20입니다."를 출력하는 프로그램을 작성하세요.

# %%
x = int(input())
if x == 10:
    print('10입니다')
if x == 20:
    print('20입니다')
# Out:
# 20
# 20입니다

# %% [markdown]
# ## 9. else 사용하여 두방향 분기

# %% [markdown]
# ### 9.1 else 사용하기
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 9.2 else 들여쓰기 규칙
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ### 9.3 if 조건문의 동작 방식
# * 조건문이 아닌 값으로 동작 시키기

# %%
if True:
    print('참')
else:
    print('거짓')

# %%
if False:
    print('참')
else:
    print('거짓')

# %%
if None:
    print('참')
else:
    print('거짓')

# %% [markdown]
# * 문자열은 내용이 있을 때는 참, 빈 문자열은 거짓
# ![image-2.png](attachment:image-2.png)

# %%
if '글자당':
    print('참')
else:
    print('거짓')

# %%
if '':
    print('참')
else:
    print('거짓')
# Out:
# 거짓

# %% [markdown]
# ### 9.4 복합 조건식 사용
# ![image.png](attachment:image.png)

# %%
x = 10
y = 20

if x == 10 and y == 20:
    print('참')
else:
    print('거짓')

# %% [markdown]
# **<연습문제> 합격여부 판단하기**
#
# A 기업은 입사 시험에서 필기 **시험 점수가 80점 이상**이면서 **토익 점수가 850점 이상**이라야 합격이라고 기준을 정했습니다. 다음 소스 코드를 완성하여 ‘합격’, ‘불합격’이 출력되게 만드세요
#
# ![image.png](attachment:image.png)

# %%
writtenTest = 75
toeic = 890

if writtenTest >= 80 and toeic >= 850:
    print('합격')
else:
    print('불합격')
# Out:
# 불합격

# %% [markdown]
# ## 10. elif 를 사용하여 두 방향 이상으로 분기하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 10.1 elif 사용
# - else인 상태에서 조건식을 지정할 때 사용하며 **else if**라는 뜻
# - if, else와 마찬가지로 조건식 뒤에 **:(콜론)**을 붙여야 함
# - elif 단독으로 사용할 수 없음

# %% [markdown]
# ### 10.2 if, elif, else 모두 사용하기
#
# ![image.png](attachment:image.png)
#
# * 앞의 음료수 자판기를 elif를 사용하여 조건식 작성
# ![image-2.png](attachment:image-2.png)

# %%
button = 1
if button == 1:
    print('콜라')
elif button == 2:
    print('사이다')
elif button == 3:
    print('환타')
else:
    print('제공하지 않는 메뉴')

# %% [markdown]
# **<연습문제>**
#
# 정수 하나를 변수 x에 입력받아, x가 11과 20 사이면 **‘11 ~ 20’**, 21과 30 사이면 **‘21~30’**, 아무것도 해당하지 않으면 **‘아무것도 해당하지 않음’** 이 출력되게 만드세요!

# %%
x = None
while (x == None):
    try:
        x = int(input('정수 입력 : '))
    except ValueError:
        print('"정수"를 입력해 주세요!')
# Out:
# 정수 입력 : 김도균 바보
# "정수"를 입력해 주세요!
# 정수 입력 : ok
# "정수"를 입력해 주세요!
# 정수 입력 : 21

# %%
if x >= 11 and x <= 20:
    print('11~20')
elif x >= 21 and x <= 30:
    print('21~30')
else: print("'아무것도 해당하지 않음'")
# Out:
# 21~30
